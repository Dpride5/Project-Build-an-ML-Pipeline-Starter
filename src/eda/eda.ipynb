# %%
# !pip install wandb==0.16.0
# !pip install ydata-profiling==4.12.1
# !pip install pandas==2.1.3
# Out:
# Collecting wandb==0.16.0
#   Downloading wandb-0.16.0-py3-none-any.whl (2.1 MB)
#                                               0.0/2.1 MB ? eta -:--:--
#      -----                                    0.3/2.1 MB 8.6 MB/s eta 0:00:01
#      ---------------------------------------  2.1/2.1 MB 26.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 22.4 MB/s eta 0:00:00
# Collecting Click!=8.0.0,>=7.1 (from wandb==0.16.0)
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#                                               0.0/98.2 kB ? eta -:--:--
#      ---------------------------------------- 98.2/98.2 kB 5.5 MB/s eta 0:00:00
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb==0.16.0)
#   Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#                                               0.0/207.6 kB ? eta -:--:--
#      ---------------------------------------- 207.6/207.6 kB ? eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from wandb==0.16.0) (2.32.2)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\dario\appdata\roaming\python\python311\site-packages (from wandb==0.16.0) (6.1.1)
# Collecting sentry-sdk>=1.0.0 (from wandb==0.16.0)
#   Downloading sentry_sdk-2.20.0-py2.py3-none-any.whl (322 kB)
#                                               0.0/322.6 kB ? eta -:--:--
#      ---------------------------------------- 322.6/322.6 kB ? eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb==0.16.0)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from wandb==0.16.0) (6.0.1)
# Collecting setproctitle (from wandb==0.16.0)
#   Downloading setproctitle-1.3.4-cp311-cp311-win_amd64.whl (12 kB)
# Requirement already satisfied: setuptools in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from wandb==0.16.0) (70.0.0)
# Collecting appdirs>=1.4.3 (from wandb==0.16.0)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting protobuf!=4.21.0,<5,>=3.19.0 (from wandb==0.16.0)
#   Downloading protobuf-4.25.6-cp310-abi3-win_amd64.whl (413 kB)
#                                               0.0/413.4 kB ? eta -:--:--
#      ---------------------------------------- 413.4/413.4 kB ? eta 0:00:00
# Requirement already satisfied: colorama in c:\users\dario\appdata\roaming\python\python311\site-packages (from Click!=8.0.0,>=7.1->wandb==0.16.0) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in c:\users\dario\appdata\roaming\python\python311\site-packages (from docker-pycreds>=0.4.0->wandb==0.16.0) (1.17.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.0)
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#                                               0.0/62.8 kB ? eta -:--:--
#      ---------------------------------------- 62.8/62.8 kB ? eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (2024.2.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.0)
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: appdirs, smmap, setproctitle, sentry-sdk, protobuf, docker-pycreds, Click, gitdb, GitPython, wandb
# Successfully installed Click-8.1.8 GitPython-3.1.44 appdirs-1.4.4 docker-pycreds-0.4.0 gitdb-4.0.12 protobuf-4.25.6 sentry-sdk-2.20.0 setproctitle-1.3.4 smmap-5.0.2 wandb-0.16.0
# [notice] A new release of pip is available: 23.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting ydata-profiling==4.12.1
#   Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl (390 kB)
#                                               0.0/390.9 kB ? eta -:--:--
#      ---------------------------            286.7/390.9 kB 5.9 MB/s eta 0:00:01
#      -------------------------------------- 390.9/390.9 kB 8.1 MB/s eta 0:00:00
# Collecting scipy<1.14,>=1.4.1 (from ydata-profiling==4.12.1)
#   Downloading scipy-1.13.1-cp311-cp311-win_amd64.whl (46.2 MB)
#                                               0.0/46.2 MB ? eta -:--:--
#      -                                        2.1/46.2 MB 46.3 MB/s eta 0:00:01
#      ---                                      4.4/46.2 MB 56.7 MB/s eta 0:00:01
#      ------                                   7.9/46.2 MB 56.5 MB/s eta 0:00:01
#      ---------                               11.6/46.2 MB 59.5 MB/s eta 0:00:01
#      -----------                             13.6/46.2 MB 59.5 MB/s eta 0:00:01
#      --------------                          16.7/46.2 MB 59.5 MB/s eta 0:00:01
#      ---------------                         18.8/46.2 MB 59.5 MB/s eta 0:00:01
#      ------------------                      21.5/46.2 MB 59.5 MB/s eta 0:00:01
#      -------------------                     23.0/46.2 MB 59.5 MB/s eta 0:00:01
#      ----------------------                  26.6/46.2 MB 54.4 MB/s eta 0:00:01
#      -------------------------               29.6/46.2 MB 59.5 MB/s eta 0:00:01
#      ---------------------------             32.1/46.2 MB 65.6 MB/s eta 0:00:01
#      ----------------------------            34.0/46.2 MB 59.5 MB/s eta 0:00:01
#      ------------------------------          36.4/46.2 MB 50.4 MB/s eta 0:00:01
#      --------------------------------        38.5/46.2 MB 50.4 MB/s eta 0:00:01
#      ----------------------------------      40.5/46.2 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------    42.9/46.2 MB 46.7 MB/s eta 0:00:01
#      --------------------------------------  45.3/46.2 MB 46.9 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 46.7 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 46.7 MB/s eta 0:00:01
#      --------------------------------------- 46.2/46.2 MB 32.7 MB/s eta 0:00:00
# Collecting pandas!=1.4.0,<3,>1.1 (from ydata-profiling==4.12.1)
#   Downloading pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
#                                               0.0/11.6 MB ? eta -:--:--
#      ------                                   2.0/11.6 MB 63.0 MB/s eta 0:00:01
#      --------------                           4.2/11.6 MB 52.5 MB/s eta 0:00:01
#      ---------------------                    6.3/11.6 MB 50.7 MB/s eta 0:00:01
#      -----------------------------            8.6/11.6 MB 50.2 MB/s eta 0:00:01
#      ------------------------------------    10.8/11.6 MB 46.7 MB/s eta 0:00:01
#      --------------------------------------- 11.6/11.6 MB 40.9 MB/s eta 0:00:00
# Collecting matplotlib<3.10,>=3.5 (from ydata-profiling==4.12.1)
#   Downloading matplotlib-3.9.4-cp311-cp311-win_amd64.whl (7.8 MB)
#                                               0.0/7.8 MB ? eta -:--:--
#      --------                                 1.6/7.8 MB 51.9 MB/s eta 0:00:01
#      ---------------------                    4.1/7.8 MB 53.0 MB/s eta 0:00:01
#      ------------------------------           6.0/7.8 MB 48.1 MB/s eta 0:00:01
#      ---------------------------------------  7.8/7.8 MB 45.5 MB/s eta 0:00:01
#      ---------------------------------------- 7.8/7.8 MB 41.9 MB/s eta 0:00:00
# Collecting pydantic>=2 (from ydata-profiling==4.12.1)
#   Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#                                               0.0/431.7 kB ? eta -:--:--
#      ------------------------------------- 431.7/431.7 kB 28.1 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling==4.12.1) (6.0.1)
# Collecting jinja2<3.2,>=2.11.1 (from ydata-profiling==4.12.1)
#   Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
#                                               0.0/134.6 kB ? eta -:--:--
#      ---------------------------------------- 134.6/134.6 kB ? eta 0:00:00
# Collecting visions[type_image_path]<0.7.7,>=0.7.5 (from ydata-profiling==4.12.1)
#   Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#                                               0.0/104.8 kB ? eta -:--:--
#      ---------------------------------------- 104.8/104.8 kB ? eta 0:00:00
# Collecting numpy<2.2,>=1.16.0 (from ydata-profiling==4.12.1)
#   Downloading numpy-2.1.3-cp311-cp311-win_amd64.whl (12.9 MB)
#                                               0.0/12.9 MB ? eta -:--:--
#      -----                                    1.8/12.9 MB 57.0 MB/s eta 0:00:01
#      -------------                            4.3/12.9 MB 54.8 MB/s eta 0:00:01
#      ---------------------                    7.0/12.9 MB 55.9 MB/s eta 0:00:01
#      -----------------------------            9.6/12.9 MB 55.5 MB/s eta 0:00:01
#      -------------------------------------   12.3/12.9 MB 59.5 MB/s eta 0:00:01
#      --------------------------------------- 12.9/12.9 MB 46.7 MB/s eta 0:00:00
# Collecting htmlmin==0.1.12 (from ydata-profiling==4.12.1)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling==4.12.1)
#   Downloading phik-0.12.4-cp311-cp311-win_amd64.whl (667 kB)
#                                               0.0/667.1 kB ? eta -:--:--
#      ------------------------------------- 667.1/667.1 kB 43.8 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling==4.12.1) (2.32.2)
# Collecting tqdm<5,>=4.48.2 (from ydata-profiling==4.12.1)
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#                                               0.0/78.5 kB ? eta -:--:--
#      ---------------------------------------- 78.5/78.5 kB 4.3 MB/s eta 0:00:00
# Collecting seaborn<0.14,>=0.10.1 (from ydata-profiling==4.12.1)
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#                                               0.0/294.9 kB ? eta -:--:--
#      ------------------------------------- 294.9/294.9 kB 17.8 MB/s eta 0:00:00
# Collecting multimethod<2,>=1.4 (from ydata-profiling==4.12.1)
#   Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling==4.12.1)
#   Downloading statsmodels-0.14.4-cp311-cp311-win_amd64.whl (9.9 MB)
#                                               0.0/9.9 MB ? eta -:--:--
#      ----------                               2.5/9.9 MB 52.7 MB/s eta 0:00:01
#      --------------------                     5.0/9.9 MB 53.4 MB/s eta 0:00:01
#      ----------------------------             7.1/9.9 MB 50.8 MB/s eta 0:00:01
#      --------------------------------------   9.4/9.9 MB 50.2 MB/s eta 0:00:01
#      ---------------------------------------- 9.9/9.9 MB 44.9 MB/s eta 0:00:00
# Collecting typeguard<5,>=3 (from ydata-profiling==4.12.1)
#   Downloading typeguard-4.4.1-py3-none-any.whl (35 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling==4.12.1)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#                                               0.0/296.5 kB ? eta -:--:--
#      ------------------------------------- 296.5/296.5 kB 19.1 MB/s eta 0:00:00
# Collecting wordcloud>=1.9.3 (from ydata-profiling==4.12.1)
#   Downloading wordcloud-1.9.4-cp311-cp311-win_amd64.whl (299 kB)
#                                               0.0/299.9 kB ? eta -:--:--
#      ------------------------------------- 299.9/299.9 kB 18.1 MB/s eta 0:00:00
# Collecting dacite>=1.8 (from ydata-profiling==4.12.1)
#   Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Collecting numba<1,>=0.56.0 (from ydata-profiling==4.12.1)
#   Downloading numba-0.61.0-cp311-cp311-win_amd64.whl (2.8 MB)
#                                               0.0/2.8 MB ? eta -:--:--
#      ---------------------------------        2.4/2.8 MB 75.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.8/2.8 MB 45.4 MB/s eta 0:00:00
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling==4.12.1)
#   Downloading pywavelets-1.8.0-cp311-cp311-win_amd64.whl (4.2 MB)
#                                               0.0/4.2 MB ? eta -:--:--
#      ----------------                         1.7/4.2 MB 52.8 MB/s eta 0:00:01
#      ---------------------------------------  4.2/4.2 MB 53.1 MB/s eta 0:00:01
#      ---------------------------------------- 4.2/4.2 MB 44.7 MB/s eta 0:00:00
# Collecting pillow (from imagehash==4.3.1->ydata-profiling==4.12.1)
#   Downloading pillow-11.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
#                                               0.0/2.6 MB ? eta -:--:--
#      ----------------------------             1.9/2.6 MB 60.8 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 MB 55.6 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0 (from jinja2<3.2,>=2.11.1->ydata-profiling==4.12.1)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl (15 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1)
#   Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl (219 kB)
#                                               0.0/219.8 kB ? eta -:--:--
#      ---------------------------------------- 219.8/219.8 kB ? eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1)
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1)
#   Downloading fonttools-4.55.6-cp311-cp311-win_amd64.whl (2.2 MB)
#                                               0.0/2.2 MB ? eta -:--:--
#      ---------------------------------------  2.2/2.2 MB 71.3 MB/s eta 0:00:01
#      ---------------------------------------- 2.2/2.2 MB 47.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1)
#   Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
#                                               0.0/72.0 kB ? eta -:--:--
#      ---------------------------------------- 72.0/72.0 kB ? eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\dario\appdata\roaming\python\python311\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (24.2)
# Collecting pyparsing>=2.3.1 (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1)
#   Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#                                               0.0/107.7 kB ? eta -:--:--
#      ---------------------------------------- 107.7/107.7 kB ? eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dario\appdata\roaming\python\python311\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (2.9.0.post0)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba<1,>=0.56.0->ydata-profiling==4.12.1)
#   Downloading llvmlite-0.44.0-cp311-cp311-win_amd64.whl (30.3 MB)
#                                               0.0/30.3 MB ? eta -:--:--
#      ---                                      2.5/30.3 MB 54.0 MB/s eta 0:00:01
#      ------                                   5.1/30.3 MB 53.7 MB/s eta 0:00:01
#      ---------                                7.4/30.3 MB 52.6 MB/s eta 0:00:01
#      ------------                             9.2/30.3 MB 49.3 MB/s eta 0:00:01
#      --------------                          11.6/30.3 MB 46.7 MB/s eta 0:00:01
#      -----------------                       13.7/30.3 MB 50.4 MB/s eta 0:00:01
#      --------------------                    16.2/30.3 MB 46.7 MB/s eta 0:00:01
#      ------------------------                18.7/30.3 MB 50.4 MB/s eta 0:00:01
#      --------------------------              21.0/30.3 MB 50.4 MB/s eta 0:00:01
#      -----------------------------           23.3/30.3 MB 50.4 MB/s eta 0:00:01
#      ---------------------------------       25.9/30.3 MB 54.4 MB/s eta 0:00:01
#      ------------------------------------    28.1/30.3 MB 50.4 MB/s eta 0:00:01
#      --------------------------------------  30.3/30.3 MB 50.1 MB/s eta 0:00:01
#      --------------------------------------  30.3/30.3 MB 50.1 MB/s eta 0:00:01
#      --------------------------------------- 30.3/30.3 MB 38.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1) (2024.1)
# Collecting tzdata>=2022.7 (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
#                                               0.0/346.8 kB ? eta -:--:--
#      ------------------------------------- 346.8/346.8 kB 22.4 MB/s eta 0:00:00
# Collecting joblib>=0.14.1 (from phik<0.13,>=0.11.1->ydata-profiling==4.12.1)
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#                                               0.0/301.8 kB ? eta -:--:--
#      ------------------------------------- 301.8/301.8 kB 18.2 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0 (from pydantic>=2->ydata-profiling==4.12.1)
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.27.2 (from pydantic>=2->ydata-profiling==4.12.1)
#   Downloading pydantic_core-2.27.2-cp311-cp311-win_amd64.whl (2.0 MB)
#                                               0.0/2.0 MB ? eta -:--:--
#      -------------------------------------    1.8/2.0 MB 59.1 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 42.0 MB/s eta 0:00:00
# Collecting typing-extensions>=4.12.2 (from pydantic>=2->ydata-profiling==4.12.1)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2024.2.2)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling==4.12.1)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#                                               0.0/232.9 kB ? eta -:--:--
#      ------------------------------------- 232.9/232.9 kB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\dario\appdata\roaming\python\python311\site-packages (from tqdm<5,>=4.48.2->ydata-profiling==4.12.1) (0.4.6)
# Collecting attrs>=19.3.0 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1)
#   Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
#                                               0.0/63.2 kB ? eta -:--:--
#      ---------------------------------------- 63.2/63.2 kB ? eta 0:00:00
# Collecting networkx>=2.4 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1)
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#                                               0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 1.7/1.7 MB 53.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\dario\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.17.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (pyproject.toml): started
#   Building wheel for htmlmin (pyproject.toml): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27140 sha256=2b7b1a82cde045b108c73b87bc6483c54e848c30773a0e7476f04f2c29caa935
#   Stored in directory: c:\users\dario\appdata\local\pip\cache\wheels\8d\55\1a\19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# Installing collected packages: htmlmin, tzdata, typing-extensions, tqdm, pyparsing, pillow, numpy, networkx, multimethod, MarkupSafe, llvmlite, kiwisolver, joblib, fonttools, dacite, cycler, attrs, annotated-types, typeguard, scipy, PyWavelets, pydantic-core, patsy, pandas, numba, jinja2, contourpy, visions, statsmodels, pydantic, matplotlib, imagehash, wordcloud, seaborn, phik, ydata-profiling
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.0
#     Uninstalling typing_extensions-4.12.0:
#       Successfully uninstalled typing_extensions-4.12.0
# Successfully installed MarkupSafe-3.0.2 PyWavelets-1.8.0 annotated-types-0.7.0 attrs-25.1.0 contourpy-1.3.1 cycler-0.12.1 dacite-1.8.1 fonttools-4.55.6 htmlmin-0.1.12 imagehash-4.3.1 jinja2-3.1.5 joblib-1.4.2 kiwisolver-1.4.8 llvmlite-0.44.0 matplotlib-3.9.4 multimethod-1.12 networkx-3.4.2 numba-0.61.0 numpy-2.1.3 pandas-2.2.3 patsy-1.0.1 phik-0.12.4 pillow-11.1.0 pydantic-2.10.6 pydantic-core-2.27.2 pyparsing-3.2.1 scipy-1.13.1 seaborn-0.13.2 statsmodels-0.14.4 tqdm-4.67.1 typeguard-4.4.1 typing-extensions-4.12.2 tzdata-2025.1 visions-0.7.6 wordcloud-1.9.4 ydata-profiling-4.12.1
# [notice] A new release of pip is available: 23.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pandas==2.1.3
#   Downloading pandas-2.1.3-cp311-cp311-win_amd64.whl (10.6 MB)
#                                               0.0/10.6 MB ? eta -:--:--
#                                               0.2/10.6 MB 7.3 MB/s eta 0:00:02
#      -------                                  2.0/10.6 MB 26.0 MB/s eta 0:00:01
#      ---------------                          4.2/10.6 MB 33.4 MB/s eta 0:00:01
#      --------------------                     5.4/10.6 MB 31.4 MB/s eta 0:00:01
#      -----------------------------            7.8/10.6 MB 35.5 MB/s eta 0:00:01
#      --------------------------------------  10.6/10.6 MB 46.7 MB/s eta 0:00:01
#      --------------------------------------- 10.6/10.6 MB 40.9 MB/s eta 0:00:00
# Collecting numpy<2,>=1.23.2 (from pandas==2.1.3)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#                                               0.0/15.8 MB ? eta -:--:--
#      ------                                   2.6/15.8 MB 83.6 MB/s eta 0:00:01
#      --------------                           5.7/15.8 MB 72.6 MB/s eta 0:00:01
#      ------------------                       7.3/15.8 MB 66.0 MB/s eta 0:00:01
#      -------------------------               10.4/15.8 MB 59.5 MB/s eta 0:00:01
#      -------------------------------         12.6/15.8 MB 59.5 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 54.4 MB/s eta 0:00:01
#      --------------------------------------- 15.8/15.8 MB 46.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dario\appdata\roaming\python\python311\site-packages (from pandas==2.1.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.1.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dario\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.1.3) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\dario\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas==2.1.3) (1.17.0)
# Installing collected packages: numpy, pandas
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# Successfully installed numpy-1.26.4 pandas-2.1.3
# [notice] A new release of pip is available: 23.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# 1. Fetch the artifact we just created (sample.csv) from W&B and read it with pandas:

# %%
import wandb
import pandas as pd
# Note that we use save_code=True in the call to wandb.init so the notebook is uploaded and versioned by W&B
run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\dario/.netrc
# wandb version 0.19.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\dario\Desktop\WGU GitHub\Project-Build-an-ML-Pipeline-Starter\src\eda\wandb\run-20250125_094652-9s5emtfx</code>
# Syncing run <strong><a href='https://wandb.ai/dpride5-western-governors-universtiy/nyc_airbnb/runs/9s5emtfx' target="_blank">graceful-armadillo-10</a></strong> to <a href='https://wandb.ai/dpride5-western-governors-universtiy/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dpride5-western-governors-universtiy/nyc_airbnb' target="_blank">https://wandb.ai/dpride5-western-governors-universtiy/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/dpride5-western-governors-universtiy/nyc_airbnb/runs/9s5emtfx' target="_blank">https://wandb.ai/dpride5-western-governors-universtiy/nyc_airbnb/runs/9s5emtfx</a>

# %% [markdown]
# 2. Explore the data in df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20000 non-null  int64
#  1   name                            19993 non-null  object
#  2   host_id                         20000 non-null  int64
#  3   host_name                       19992 non-null  object
#  4   neighbourhood_group             20000 non-null  object
#  5   neighbourhood                   20000 non-null  object
#  6   latitude                        20000 non-null  float64
#  7   longitude                       20000 non-null  float64
#  8   room_type                       20000 non-null  object
#  9   price                           20000 non-null  int64
#  10  minimum_nights                  20000 non-null  int64
#  11  number_of_reviews               20000 non-null  int64
#  12  last_review                     15877 non-null  object
#  13  reviews_per_month               15877 non-null  float64
#  14  calculated_host_listings_count  20000 non-null  int64
#  15  availability_365                20000 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.000000e+04  2.000000e+04  20000.000000  20000.000000  20000.000000
# mean   1.892380e+07  6.746034e+07     40.728455    -73.952125    153.269050
# std    1.101223e+07  7.857936e+07      0.054755      0.046559    243.325609
# min    2.539000e+03  2.571000e+03     40.508730    -74.239140      0.000000
# 25%    9.393540e+06  7.853718e+06     40.689420    -73.983030     69.000000
# 50%    1.952117e+07  3.111431e+07     40.722730    -73.955640    105.000000
# 75%    2.912936e+07  1.068426e+08     40.762990    -73.936380    175.000000
# max    3.648561e+07  2.742733e+08     40.913060    -73.717950  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20000.000000       20000.000000       15877.000000
# mean         6.992100          23.274100           1.377446
# std         21.645449          44.927793           1.683006
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          2.000000           5.000000           0.720000
# 75%          5.000000          23.000000           2.010000
# max       1250.000000         607.000000          27.950000
#
#        calculated_host_listings_count  availability_365
# count                    20000.000000      20000.000000
# mean                         6.955450        112.901200
# std                         32.433831        131.762226
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         44.000000
# 75%                          2.000000        229.000000
# max                        327.000000        365.000000

# %%
df.head()
# Out:
#          id                                               name    host_id  \
# 0   9138664                Private Lg Room 15 min to Manhattan   47594947
# 1  31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2   8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3  34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4  23203149   Big beautiful bedroom in huge Bushwick apartment     143460
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0      Iris              Queens       Sunnyside  40.74271  -73.92493
# 1    Johlex           Manhattan  Hell's Kitchen  40.76682  -73.98878
# 2      John           Manhattan    West Village  40.73631  -74.00611
# 3     Regan              Queens         Astoria  40.76424  -73.92351
# 4     Megan            Brooklyn        Bushwick  40.69839  -73.92044
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     74               2                  6  2019-05-26
# 1  Entire home/apt    170               3                  0         NaN
# 2  Entire home/apt    245               3                 51  2018-09-19
# 3  Entire home/apt    125               3                  1  2019-05-24
# 4     Private room     65               2                  8  2019-06-23
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.13                               1                 5
# 1                NaN                               1               188
# 2               1.12                               1                 0
# 3               0.65                               1                13
# 4               0.52                               2                 8

# %% [markdown]
# 3. What do you notice in the data? Look around and see what you can find.
#
# > For example, there are missing values in a few columns and the column `last_review` is a date but it is in string format. Look also at the `price` column, and note the outliers. There are some zeros and some very high prices. After talking to your stakeholders, you decide to consider from a minimum of `$10` to a maximum of `$350` per night.

# %% [markdown]
# 4. Fix some of the little problems we have found in the data with the following code:

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %% [markdown]
# Note how we did not impute missing values. We will do that in the inference pipeline, so we will be able to handle missing values also in production.

# %% [markdown]
# 5. Check with df.info() that all obvious problems have been solved

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %% [markdown]
# 6. Terminate the run by running `run.finish()`

# %%
run.finish()
# Out:
#  View run <strong style="color:#cdcd00">graceful-armadillo-10</strong> at: <a href='https://wandb.ai/dpride5-western-governors-universtiy/nyc_airbnb/runs/9s5emtfx' target="_blank">https://wandb.ai/dpride5-western-governors-universtiy/nyc_airbnb/runs/9s5emtfx</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>.\wandb\run-20250125_094652-9s5emtfx\logs</code>

# %% [markdown]
# 7. Save the notebook.
